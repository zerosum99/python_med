# %% [markdown]
# ## pip install midi-clip
#
# https://github.com/kyaryunha/midi-clip

# %%
import mido
import midi_clip

# %%
dir(midi_clip)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'midi_clip',
#  'midi_duration']

# %%
mido.__version__
# Out:
# '1.2.10'

# %%
dir(mido)
# Out:
# ['Backend',
#  'KeySignatureError',
#  'MAX_PITCHWHEEL',
#  'MAX_SONGPOS',
#  'MIN_PITCHWHEEL',
#  'MIN_SONGPOS',
#  'Message',
#  'MetaMessage',
#  'MidiFile',
#  'MidiTrack',
#  'Parser',
#  'UnknownMetaMessage',
#  '__about__',
#  '__all__',
#  '__author__',
#  '__author_email__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__url__',
#  '__version__',
#  'backend',
#  'backends',
#  'bpm2tempo',
#  'format_as_string',
#  'get_input_names',
#  'get_ioport_names',
#  'get_output_names',
#  'merge_tracks',
#  'messages',
#  'midifiles',
#  'open_input',
#  'open_ioport',
#  'open_output',
#  'parse',
#  'parse_all',
#  'parse_string',
#  'parse_string_stream',
#  'parser',
#  'ports',
#  'py2',
#  'read_syx_file',
#  'second2tick',
#  'set_backend',
#  'sockets',
#  'syx',
#  'tempo2bpm',
#  'tick2second',
#  'tokenizer',
#  'version',
#  'version_info',
# ...

# %%
midi-clip/example/

# %%
# load midi use mido
mid = mido.MidiFile('./다시 만나줘-업타운.mid')

# %%
# clip midi
output_mid = midi_clip.midi_clip(mid, 5., 15.)
# you can get total duration(second) of midi
duration = midi_clip.midi_duration(output_mid)
# if you see by print
print(output_mid, duration)
# if you save midi clip
#output_mid.save('output.mid')
# Out:
# MidiFile(type=1, ticks_per_beat=120, tracks=[
#   MidiTrack([
#     MetaMessage('track_name', name='´Ù½Ã ¸¸³ªÁà', time=0),
#     MetaMessage('track_name', name='¾÷ Å¸¿î', time=0),
#     MetaMessage('set_tempo', tempo=545455, time=0),
#     MetaMessage('end_of_track', time=0)]),
#   MidiTrack([
#     MetaMessage('track_name', name='BASS', time=0),
#     Message('control_change', channel=1, control=7, value=110, time=0),
#     Message('control_change', channel=1, control=10, value=64, time=0),
#     Message('control_change', channel=1, control=91, value=0, time=0),
#     Message('control_change', channel=1, control=93, value=0, time=0),
#     Message('control_change', channel=1, control=100, value=0, time=0),
#     Message('control_change', channel=1, control=101, value=0, time=0),
#     Message('control_change', channel=1, control=6, value=12, time=0),
#     Message('note_on', channel=1, note=33, velocity=105, time=0),
# ...
